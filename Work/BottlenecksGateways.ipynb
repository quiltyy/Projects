# %%
import pandas as pd

# %%
bg = pd.read_csv('Bottleneck_Gateways.csv')

# %%
bg.head()
# Out:
#    AcademicQtrKeyId AcademicYrName  CourseCampus     FinCollegeReportingName  \
# 0             20231      2022/2023             2  Milgard School of Business
# 1             20234      2023/2024             2  Milgard School of Business
# 2             20211      2020/2021             2  Milgard School of Business
# 3             20224      2022/2023             2  Milgard School of Business
# 4             20184      2018/2019             2  Milgard School of Business
#
#    FinDepartmentReportingName  CourseLevelNbr CourseSectionCode  \
# 0  Milgard School of Business             200    2_T ACCT_210_A
# 1  Milgard School of Business             200    2_T ACCT_210_A
# 2  Milgard School of Business             200    2_T ACCT_210_A
# 3  Milgard School of Business             200    2_T ACCT_210_A
# 4  Milgard School of Business             200    2_T ACCT_210_A
#
#   CurriculumAbbrCode  CourseNbr     Course  ... simple_faculty_load_SCH  \
# ...

# %%
bgGroup = bg.groupby('Course')[is_bottleneck]
